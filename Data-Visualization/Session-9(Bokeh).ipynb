# %% [markdown]
# # Bokeh Tutorial <br>
# https://towardsdatascience.com/data-visualization-with-bokeh-in-python-part-one-getting-started-a11655a467d4

# %%
# !pip install bokeh
# Out:
# ...
#     100% |████████████████████████████████| 16.3MB 2.7MB/s
# ...
#   Running setup.py bdist_wheel for bokeh ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/7c/cc/1c/a8f447869feb88844eed88b9524f1974ff6219c9b586b3bfab
# Successfully built bokeh
# ...

# %%
ls -al
# Out:
# total 13784
# drwxrwsr-x  3 jupyterlab resources     4096 Feb  5 06:43 ./
# drwxrwsr-x 16 jupyterlab resources     4096 Feb  5 05:24 ../
# drwxrwsr-x  2 jupyterlab resources     4096 Feb  5 06:43 .ipynb_checkpoints/
# -rw-r--r--  1 jupyterlab resources     7992 Apr 30  2017 Pokemon.csv
# -rw-r--r--  1 jupyterlab resources    50176 Feb  5 05:25 Presidents.xls
# -rw-rw-r--  1 jupyterlab resources 11699220 Feb  5 05:31 Session-5(Python data visualization Comparing 7 tools).ipynb
# -rw-rw-r--  1 jupyterlab resources   734712 Feb  5 05:26 Session-7(Data Visualization).ipynb
# -rw-r--r--  1 jupyterlab resources  1067369 Feb  5 06:43 Session-9(Seaborn).ipynb
# -rw-r--r--  1 jupyterlab resources    32968 Feb  5 05:25 Session_8(PLOT_ly_Data_Visualization).ipynb
# -rw-r--r--  1 jupyterlab resources   152843 Feb  5 06:43 Tutorial_Bokeh_01.ipynb
# -rw-r--r--  1 jupyterlab resources       72 Feb  5 06:43 Untitled.ipynb
# ...

# %% [markdown]
# # Download NYC Flight Data<br>
# https://github.com/hadley/nycflights13

# %%
# !wget https://raw.githubusercontent.com/hadley/nycflights13/master/data-raw/airlines.csv
# !wget https://raw.githubusercontent.com/hadley/nycflights13/master/data-raw/airports.csv
# !wget https://raw.githubusercontent.com/hadley/nycflights13/master/data-raw/planes.csv
# !wget https://raw.githubusercontent.com/hadley/nycflights13/master/data-raw/weather.csv
# Out:
# --2019-02-05 06:44:09--  https://raw.githubusercontent.com/hadley/nycflights13/master/data-raw/airlines.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.124.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.124.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 386 [text/plain]
# Saving to: ‘airlines.csv’
#
# airlines.csv        100%[=====================>]     386  --.-KB/s   in 0s
#
# 2019-02-05 06:44:09 (5.96 MB/s) - ‘airlines.csv’ saved [386/386]
#
# --2019-02-05 06:44:10--  https://raw.githubusercontent.com/hadley/nycflights13/master/data-raw/airports.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.124.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.124.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 107218 (105K) [text/plain]
# Saving to: ‘airports.csv’
#
# ...

# %%
#flights data is not available in CSV format at the github repository
#it is available https://data.world/bob-wakefield/flights#
#get it from here
# ----------------
# !wget -O flights.csv https://query.data.world/s/ouejfpckpkhi6wvuj2qflzsc55bf7g
# Out:
# --2019-02-05 06:44:12--  https://query.data.world/s/ouejfpckpkhi6wvuj2qflzsc55bf7g
# Resolving query.data.world (query.data.world)... 54.210.161.152, 18.211.24.14
# Connecting to query.data.world (query.data.world)|54.210.161.152|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://download.data.world/file_download/bob-wakefield/flights/flights.csv?auth=eyJhbGciOiJIUzUxMiJ9..2lXPOi4e0VFBfMF8YhH66XnmKmzklGi4KnBbmGLods0TbvU0BVCGQ7tQUL-ci7ANmj6mkcPeYRKUecJX3MoFjw [following]
# ...

# %% [markdown]
# # Basics

# %%
# bokeh basics
from bokeh.plotting import figure
from bokeh.io import show, output_notebook

# %%
# Create a blank figure with labels
p = figure(plot_width = 600, plot_height = 600, 
           title = 'Example Glyphs',
           x_axis_label = 'X', y_axis_label = 'Y')

# Example data
squares_x = [1, 3, 4, 5, 8]
squares_y = [8, 7, 3, 1, 10]
circles_x = [9, 12, 4, 3, 15]
circles_y = [8, 4, 11, 6, 10]

# Add squares glyph
p.square(squares_x, squares_y, size = 12, color = 'navy', alpha = 0.6)
# Add circle glyph
p.circle(circles_x, circles_y, size = 12, color = 'red')

# Set to output the plot in the notebook
output_notebook()
# Show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1047">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="601168f1-2a35-45b2-8915-44f832d99a29" data-root-id="1002"></div>

# %% [markdown]
# # Delay - Histogram

# %%
import pandas as pd
# Read the data from a csv into a dataframe
flights = pd.read_csv('flights.csv', index_col=0)
# Summary stats for the column of interest
flights['arr_delay'].describe()
# Out:
# count    327346.000000
# mean          6.895377
# std          44.633292
# min         -86.000000
# 25%         -17.000000
# 50%          -5.000000
# 75%          14.000000
# max        1272.000000
# Name: arr_delay, dtype: float64

# %%
import numpy as np
arr_hist, edges = np.histogram(flights['arr_delay'], 
                               bins = int(180/5), 
                               range = [-60, 120])
# Put the information in a dataframe
delays = pd.DataFrame({'flights': arr_hist, 
                       'left': edges[:-1], 
                       'right': edges[1:]})
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/numpy/lib/histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/jupyterlab/conda/lib/python3.6/site-packages/numpy/lib/histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
delays.count()
# Out:
# flights    36
# left       36
# right      36
# dtype: int64

# %%
delays.head(4)
# Out:
#    flights  left  right
# 0      276 -60.0  -55.0
# 1      636 -55.0  -50.0
# 2     1394 -50.0  -45.0
# 3     2820 -45.0  -40.0

# %%
# Create the blank plot
p2 = figure(plot_height = 600, plot_width = 600, 
           title = 'Histogram of Arrival Delays',
          x_axis_label = 'Delay (min)]', 
           y_axis_label = 'Number of Flights')

# Add a quad glyph
p2.quad(bottom=0, top=delays['flights'], 
       left=delays['left'], right=delays['right'], 
       fill_color='blue')

# Show the plot
output_notebook()
show(p2)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1159">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="9f4d8c0f-a997-4ce4-975c-1cde0ec40533" data-root-id="1119"></div>

# %%
# Add a column showing the extent of each interval
delays['f_interval'] = ['%d to %d minutes' % (left, right) for left, right in zip(delays['left'], delays['right'])]
delays['f_flights'] = ['%d flights' % (x) for x in delays['flights']]
delays.head(5)
# Out:
#    flights  left  right          f_interval     f_flights
# 0      276 -60.0  -55.0  -60 to -55 minutes   276 flights
# 1      636 -55.0  -50.0  -55 to -50 minutes   636 flights
# 2     1394 -50.0  -45.0  -50 to -45 minutes  1394 flights
# 3     2820 -45.0  -40.0  -45 to -40 minutes  2820 flights
# 4     5339 -40.0  -35.0  -40 to -35 minutes  5339 flights

# %%
# Import the ColumnDataSource class
from bokeh.models import ColumnDataSource
# Convert dataframe to column data source
src = ColumnDataSource(delays)
src.data.keys()
# Out:
# dict_keys(['index', 'flights', 'left', 'right', 'f_interval', 'f_flights'])

# %%
# Create the blank plot
p = figure(plot_height = 600, plot_width = 600, 
           title = 'Histogram of Arrival Delays',
          x_axis_label = 'Delay (min)]', 
           y_axis_label = 'Number of Flights')

# Add a quad glyph with source this time
p.quad(bottom=0, top='flights', left='left', right='right', source=src,
       fill_color='red', line_color='black', fill_alpha = 0.75,
       hover_fill_alpha = 1.0, hover_fill_color = 'navy')
# Out:
# GlyphRenderer(id='1267', ...)

# %%
from bokeh.models import HoverTool
# Add a hover tool referring to the formatted columns
hover = HoverTool(tooltips = [('Delay', '@f_interval'),
                             ('Num of Flights', '@f_flights')])

# Style the plot
#p = style(p)

# Add the hover tool to the graph
p.add_tools(hover)

# %%
# Show the plot
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1273">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f3588476-5c99-4cdd-8de4-58953915246c" data-root-id="1228"></div>
